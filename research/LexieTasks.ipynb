# %%
pwd
# Out:
# 'C:\\Users\\lexie\\PycharmProjects\\SocSIM\\research'

# %%
cd ..
# Out:
# C:\Users\lexie\PycharmProjects\SocSIM

# %%
from SOC.models import BTW

# %%
b = BTW(15)

# %%
b.plot_state();

# %%
b.drive(4000)

# %%
b.plot_state();

# %%
b.run(400)

# %%
b.plot_state();

# %%
b.animate_states(True)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
b.plot_histogram();

# %%
a = BTW(100, wait_for_n_iters = 0)
a.drive(4000)
a.run(40000)
a.plot_histogram();
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-96df328db166> in <module>
#       1 a = BTW(100, wait_for_n_iters = 0)
#       2 a.drive(4000)
# ----> 3 a.run(40000)
#       4 a.plot_histogram();
#
# ~\PycharmProjects\SocSIM\SOC\common\simulation.py in run(self, N_iterations, density, filename)
#     128             self.drive(int(density*self.L*self.L))
#     129
# --> 130             observables = self.AvalancheLoop()
#     131             if i >= self.wait_for_n_iters:
#     132                 self.data_acquisition.append(observables)
#
# ~\PycharmProjects\SocSIM\SOC\common\simulation.py in AvalancheLoop(self)
#      88         number_of_iterations = 0 # TODO rename number_of_topples/czas rozsypywania/duration
#      89         self.visited[...] = False
# ---> 90         while self.topple():
#      91             self.dissipate()
# ...

# %%
c = BTW(100, wait_for_n_iters = 1000)
c.drive(4000)
c.run(40000)
c.plot_histogram();
