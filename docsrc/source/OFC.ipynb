# %% [markdown]
# # OFC Earthquake Model

# %%
from SOC.models import OFC
sim = OFC(1, 0.25, L=35, save_every = 10000)
sim.run(100000, wait_for_n_iters = 100000)
# Out:
# Waiting for wait_for_n_iters=100000 iterations before collecting data. This should let the system thermalize.
# ...

# %%
sim.get_exponent()
# Out:
# y = 26546.746 exp(-1.0912 x)
# {'exponent': -1.0912279141095085, 'intercept': 4.424011295008359}

# %%
from SOC.models import OFC
sim2 = OFC(1, 0.1, L=35, save_every = 10000)
sim2.run(100000, wait_for_n_iters = 100000)
# Out:
# Waiting for wait_for_n_iters=100000 iterations before collecting data. This should let the system thermalize.
# ...

# %%
sim2.get_exponent()
# Out:
# y = 57760.423 exp(-3.1341 x)
# {'exponent': -3.1341062436943257, 'intercept': 4.761630367570278}

# %%
sim.animate_states(notebook=True)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
